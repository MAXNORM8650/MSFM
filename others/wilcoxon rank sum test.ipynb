# %%
import scipy

# %%
import pandas as pd

# %%
d=pd.read_excel(r"C:\Users\Admin\Dropbox\PC\Downloads\Wicoskin_data.xlsx")

# %%
d
# Out:
#    Unnamed: 0 Unnamed: 1  Res Net  Dense Net  Inception  OurNetR18  OurNetR34  \
# 0       ELBOW         P1     0.87       0.88       0.85       0.94       0.83
# 1         NaN         P2     0.87       0.85       0.83       0.78       0.78
# 2         NaN         R1     0.75       0.76       0.74       0.73       0.76
# 3         NaN         R2     0.92       0.92       0.91       0.96       0.85
# 4      FINGER         P3     0.83       0.79       0.84       0.87       0.88
# 5         NaN         P4     0.84       0.81       0.84       0.65       0.71
# 6         NaN         R3     0.74       0.68       0.74       0.59       0.68
# 7         NaN         R4     0.90       0.88       0.91       0.90       0.90
# 8     FOREARM         P5     0.87       0.81       0.88       0.98       0.95
# 9         NaN         P6     0.84       0.83       0.86       0.63       0.70
# 10        NaN         R5     0.72       0.72       0.75       0.41       0.59
# ...

# %%
group4=d['OurNetR18']
group5=d['OurNetR34']
group6=d['OurNetR50']
group1=d['Res Net']
group2=d['Dense Net']
group3=d['Inception']

# %%
import scipy.stats as stats

# %%
scipy.stats.ranksums(group2, group2)
# Out:
# RanksumsResult(statistic=-1.3355273078893417, pvalue=0.18170382376261363)

# %%
scipy.stats.ranksums(group2, group3)
# Out:
# RanksumsResult(statistic=0.9176629354822471, pvalue=0.3587953578869416)

# %%
scipy.stats.ranksums(group3, group4)
# Out:
# RanksumsResult(statistic=0.8603090020146066, pvalue=0.3896187319493748)

# %%
scipy.stats.ranksums(group3, group5)
# Out:
# RanksumsResult(statistic=1.8353258709644942, pvalue=0.06645742001693117)

# %%
scipy.stats.ranksums(group3, group6)
# Out:
# RanksumsResult(statistic=0.8685024210814124, pvalue=0.38511934748212173)

# %%
x,y=stats.wilcoxon(group2, group3)

# %%
path=r"C:\Users\Admin\OneDrive - Reliance Foundation Institution of Education and Research\Wil_results.xlsx"

# %%
df=pd.read_excel(path)

# %%
# Out:
#     Algorithm Statistic Measures   Res Net  Dense Net  Inception  OurNetR18  \
# 0     Res Net       z-statistics  0.000000  -1.335527  -0.360510   0.573539
# 1         NaN            p-value  1.000000   0.181704   0.718465   0.566280
# 2   Dense Net       z-statistics -1.335527   0.000000   0.566280   1.409268
# 3         NaN            p-value  0.181704   1.000000   0.358795   0.158756
# 4   Inception       z-statistics -0.360510   0.566280   0.000000   0.860309
# 5         NaN            p-value  0.718465   0.358795   1.000000   0.389619
# 6   OurNetR18       z-statistics  0.573539   1.409268   0.860309   0.000000
# 7         NaN            p-value  0.566280   0.158756   0.389619   1.000000
# 8   OurNetR34       z-statistics  1.810746   2.335124   0.389619   0.278576
# 9         NaN            p-value  0.070180   0.019537   0.066457   0.780570
# 10  OurNetR50       z-statistics  0.573539   1.499396   0.868502  -0.491605
# ...

# %%
import seaborn as sns

# %%
dff
# Out:
#     Algorithm Statistic Measures   Res Net  Dense Net  Inception  OurNetR18  \
# 1         NaN            p-value  1.000000   0.181704   0.718465   0.566280
# 2   Dense Net       z-statistics -1.335527   0.000000   0.566280   1.409268
# 3         NaN            p-value  0.181704   1.000000   0.358795   0.158756
# 4   Inception       z-statistics -0.360510   0.566280   0.000000   0.860309
# 5         NaN            p-value  0.718465   0.358795   1.000000   0.389619
# 6   OurNetR18       z-statistics  0.573539   1.409268   0.860309   0.000000
# 7         NaN            p-value  0.566280   0.158756   0.389619   1.000000
# 8   OurNetR34       z-statistics  1.810746   2.335124   0.389619   0.278576
# 9         NaN            p-value  0.070180   0.019537   0.066457   0.780570
# 10  OurNetR50       z-statistics  0.573539   1.499396   0.868502  -0.491605
# 11        NaN            p-value  0.566280   0.133771   0.385119   0.622999
#
#     OurNetR34  OurNetR50
# 1    0.070180   0.566280
# ...
